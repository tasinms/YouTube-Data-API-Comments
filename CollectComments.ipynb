# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('MovieTitleTrailerID.csv')

df.head()
# Out:
#    ID            Title   Trailer ID
# 0   0      Daybreakers  U6NmZS9CTKE
# 1   1        Leap Year  HrlQBsd8LsE
# 2   2  Youth in Revolt  1gBnVf130uU
# 3   3  Wonderful World  n2_4asPVgOQ
# 4   4  The Book of Eli  zSMHmtaoXtI

# %%
df.isnull().sum()
# Out:
# ID            0
# Title         0
# Trailer ID    0
# dtype: int64

# %%
# true = True

# response = {
#   "kind": "youtube#commentThreadListResponse",
#   "etag": "LVZM4xrqwbWuYJXa4h8nriNf_Ws",
#   "nextPageToken": "Z2V0X3JhbmtlZF9zdHJlYW1zLS1DaTBJZ0FRVkY3ZlJPQm9qQ2g4STJGOFFnQVFZQnlJVko4LW9ILXI5bnYweW1tMG82dU81SU5VY1R0NEJFQUlTQlFpSUlCZ0FFZ1VJaHlBWUFCSUZDS2dnR0FBU0JRaUpJQmdBRWdjSWhTQVFBaGdCRWdjSWhDQVFBaGdCR0FB",
#   "pageInfo": {
#     "totalResults": 2,
#     "resultsPerPage": 2
#   },
#   "items": [
#     {
#       "kind": "youtube#commentThread",
#       "etag": "qlHC53mypjXj_U5WekY7v78D7js",
#       "id": "Ugy43W-8QW2i2yeDUhN4AaABAg",
#       "snippet": {
#         "channelId": "UCz97F7dMxBNOfGYu3rx8aCw",
#         "videoId": "DqQe3OrsMKI",
#         "topLevelComment": {
#           "kind": "youtube#comment",
#           "etag": "c9Vlej1dXVTh2_mHdWY7CJpc5Uk",
#           "id": "Ugy43W-8QW2i2yeDUhN4AaABAg",
#           "snippet": {
#             "channelId": "UCz97F7dMxBNOfGYu3rx8aCw",
#             "videoId": "DqQe3OrsMKI",
#             "textDisplay": "They made her look exactly like she was described in the book. Small frame, small nose, high cheekbones. Unconventional short hairstyle, black emo-ish theme but weirdly attractive.  Rooney Mara is the most *PERFECT* casting in a movie adaption I have seen in a loooong time.",
#             "textOriginal": "They made her look exactly like she was described in the book. Small frame, small nose, high cheekbones. Unconventional short hairstyle, black emo-ish theme but weirdly attractive.  Rooney Mara is the most *PERFECT* casting in a movie adaption I have seen in a loooong time.",
#             "authorDisplayName": "@EliteNormie",
#             "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AIdro_l0st2vD4KfjCB__eghh2DQy3UDVMXEhBSWg0IG-2KMNd0=s48-c-k-c0x00ffffff-no-rj",
#             "authorChannelUrl": "http://www.youtube.com/@EliteNormie",
#             "authorChannelId": {
#               "value": "UCEuGi2JEbfaFd6od9JiNKKg"
#             },
#             "canRate": true,
#             "viewerRating": "none",
#             "likeCount": 2757,
#             "publishedAt": "2020-01-15T06:30:44Z",
#             "updatedAt": "2020-01-15T06:30:44Z"
#           }
#         },
#         "canReply": true,
#         "totalReplyCount": 21,
#         "isPublic": true
#       }
#     },
#     {
#       "kind": "youtube#commentThread",
#       "etag": "lXlNSvdsXAmsCBxfpJqTcbjQ-4c",
#       "id": "UgzQWOxWIPhgz5LDV0x4AaABAg",
#       "snippet": {
#         "channelId": "UCz97F7dMxBNOfGYu3rx8aCw",
#         "videoId": "DqQe3OrsMKI",
#         "topLevelComment": {
#           "kind": "youtube#comment",
#           "etag": "MyDisfE-f_2S3dQLwSzFc3oqN-I",
#           "id": "UgzQWOxWIPhgz5LDV0x4AaABAg",
#           "snippet": {
#             "channelId": "UCz97F7dMxBNOfGYu3rx8aCw",
#             "videoId": "DqQe3OrsMKI",
#             "textDisplay": "The best thing is that they didn't try to make Salander \"sexy\" in a Hollywood way, but stayed true to the character.",
#             "textOriginal": "The best thing is that they didn't try to make Salander \"sexy\" in a Hollywood way, but stayed true to the character.",
#             "authorDisplayName": "@gringochucha",
#             "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AIdro_l7ItHWXiOBFV8YEN3dKjJ8xHaZP1hZ_sK7BiF4I0tjOQ=s48-c-k-c0x00ffffff-no-rj",
#             "authorChannelUrl": "http://www.youtube.com/@gringochucha",
#             "authorChannelId": {
#               "value": "UCKtM9H1AHARUvVUEejHATzg"
#             },
#             "canRate": true,
#             "viewerRating": "none",
#             "likeCount": 3518,
#             "publishedAt": "2017-11-14T10:14:06Z",
#             "updatedAt": "2017-11-14T10:14:06Z"
#           }
#         },
#         "canReply": true,
#         "totalReplyCount": 19,
#         "isPublic": true
#       }
#     }
#   ]
# }

# %%
# response['items'][0]['snippet']['topLevelComment']['snippet']['textDisplay']

# %%
# def removeQuotations(sentence):
#     return sentence.strip("'")

# items = response['items']

# comments = [item['snippet']['topLevelComment']['snippet']['textDisplay'].strip("'") for item in items]
# print(comments)

# %%
# import requests
# import json
# from urllib.parse import quote

# def removeQuotations(sentence):
#     return sentence.strip("'")

# apiKey = 'AIzaSyC8VjUjr_22_ZGKrutUOiUITmn7vsMQeOs'

# maxResults = '100'
# startingIndex = 0

# # Iterate over each row in the DataFrame
# for index, row in df.iloc[startingIndex:].iterrows():
    
#     title = row['Title']
#     videoId = row['Trailer ID']

#     request = f'https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&maxResults={maxResults}&videoId={videoId}&key={apiKey}&textFormat=plainText&order=relevance'

#     response = requests.get(request)

#     items = response.json()['items']
#     for item in items:
#         comment = removeQuotations(item['snippet']['topLevelComment']['snippet']['textDisplay'])
#         print(comment)

# df.head()

# %%
# import requests
# import json
# from urllib.parse import quote

# apiKey = 'AIzaSyC8VjUjr_22_ZGKrutUOiUITmn7vsMQeOs'

# maxResults = '100'
# startingIndex = 0

# # Create an empty DataFrame to store the comments
# commentsDF = pd.DataFrame(columns=['ID', 'Title', 'Trailer ID', 'Comment'])

# # Iterate over each row in the DataFrame
# for index, row in df.iloc[startingIndex:3].iterrows():
#     id = row['ID']
#     title = row['Title']
#     videoId = row['Trailer ID']

#     request = f'https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&maxResults={maxResults}&videoId={videoId}&key={apiKey}&textFormat=plainText&order=relevance'

#     response = requests.get(request)

#     if response.status_code == 200:
#         items = response.json()['items']
#         comments = [item['snippet']['topLevelComment']['snippet']['textDisplay'].strip("'") for item in items]
#         for comment in comments:
#             print(comment)
#     else:
#         print("Failed")

# %%
import requests
import json
from urllib.parse import quote

apiKey = 'AIzaSyC8VjUjr_22_ZGKrutUOiUITmn7vsMQeOs'

maxResults = '100'
startingIndex = 0

movieCommentsList = []
movieFailuresList = []

# Iterate over each row in the DataFrame
for index, row in df.iloc[startingIndex:].iterrows():
    id = row['ID']
    title = row['Title']
    videoId = row['Trailer ID']


    request = f'https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&maxResults={maxResults}&videoId={videoId}&key={apiKey}&textFormat=plainText&order=relevance'

    response = requests.get(request)

    if response.status_code == 200:
        
        items = response.json()['items']
        comments = [item['snippet']['topLevelComment']['snippet']['textDisplay'].strip("'") for item in items]
        
        # Iterate over each comment for the current movie
        for comment in comments:
            movieComments = {}
            
            movieComments['ID'] = id
            movieComments['Title'] = title
            movieComments['Trailer ID'] = videoId
            movieComments['Comment'] = comment
            
            movieCommentsList.append(movieComments)
    else:
        
        movieFailures = {}

        movieFailures['ID'] = id
        movieFailures['Title'] = title
        movieFailures['Trailer ID'] = videoId
        movieFailures['Status Code'] = response.status_code
        
        movieFailuresList.append(movieFailures)
        
        print(f'Failed to get video ID for title: {title} at index {index} with status code: {response.status_code}')
# Out:
# Failed to get video ID for title: How to Train Your Dragon at index 45 with status code: 403
# Failed to get video ID for title: Letters to God at index 52 with status code: 403
# Failed to get video ID for title: Robin Hood at index 71 with status code: 403
# Failed to get video ID for title: Shrek Forever After at index 75 with status code: 403
# Failed to get video ID for title: Survival of the Dead at index 83 with status code: 403
# Failed to get video ID for title: Toy Story 3 at index 94 with status code: 403
# Failed to get video ID for title: Despicable Me at index 105 with status code: 403
# Failed to get video ID for title: Standing Ovation at index 112 with status code: 403
# Failed to get video ID for title: Middle Men at index 125 with status code: 403
# Failed to get video ID for title: Legend of the Guardians: The Owls of Ga'Hoole at index 153 with status code: 403
# Failed to get video ID for title: Megamind at index 178 with status code: 403
# Failed to get video ID for title: Transformers: Revenge of the Fallen at index 179 with status code: 403
# Failed to get video ID for title: Tangled at index 191 with status code: 403
# Failed to get video ID for title: Diary of a Wimpy Kid: Rodrick Rules at index 244 with status code: 403
# Failed to get video ID for title: Hop at index 247 with status code: 403
# Failed to get video ID for title: Kung Fu Panda 2 at index 276 with status code: 403
# Failed to get video ID for title: Judy Moody and the Not Bummer Summer at index 283 with status code: 403
# Failed to get video ID for title: Mr. Popper's Penguins at index 288 with status code: 403
# Failed to get video ID for title: Cars 2 at index 291 with status code: 403
# Failed to get video ID for title: Winnie the Pooh at index 299 with status code: 403
# Failed to get video ID for title: The Smurfs at index 307 with status code: 403
# Failed to get video ID for title: Seven Days in Utopia at index 322 with status code: 403
# Failed to get video ID for title: Puss in Boots at index 356 with status code: 403
# Failed to get video ID for title: Happy Feet Two at index 365 with status code: 403
# Failed to get video ID for title: Arthur Christmas at index 368 with status code: 403
# Failed to get video ID for title: The Muppets at index 370 with status code: 403
# Failed to get video ID for title: Alvin and the Chipmunks: Chipwrecked at index 380 with status code: 403
# Failed to get video ID for title: Journey 2: The Mysterious Island at index 411 with status code: 403
# Failed to get video ID for title: The Lorax at index 419 with status code: 403
# Failed to get video ID for title: Wrath of the Titans at index 432 with status code: 403
# Failed to get video ID for title: Chimpanzee at index 439 with status code: 403
# Failed to get video ID for title: Madagascar 3: Europe's Most Wanted at index 463 with status code: 403
# Failed to get video ID for title: Rock of Ages at index 466 with status code: 403
# Failed to get video ID for title: Brave at index 470 with status code: 403
# Failed to get video ID for title: Ice Age: Continental Drift at index 483 with status code: 403
# Failed to get video ID for title: Diary of a Wimpy Kid: Dog Days at index 489 with status code: 403
# Failed to get video ID for title: ParaNorman at index 497 with status code: 403
# Failed to get video ID for title: The Oogieloves in the Big Balloon Adventure at index 505 with status code: 403
# Failed to get video ID for title: Hotel Transylvania at index 521 with status code: 403
# Failed to get video ID for title: Wreck-It Ralph at index 544 with status code: 403
# Failed to get video ID for title: Skyfall at index 547 with status code: 403
# Failed to get video ID for title: Rise of the Guardians at index 553 with status code: 403
# Failed to get video ID for title: Zero Dark Thirty at index 562 with status code: 403
# Failed to get video ID for title: Escape from Planet Earth at index 594 with status code: 403
# Failed to get video ID for title: The Croods at index 607 with status code: 403
# Failed to get video ID for title: G.I. Joe: Retaliation at index 610 with status code: 403
# Failed to get video ID for title: What Maisie Knew at index 626 with status code: 403
# Failed to get video ID for title: Epic at index 636 with status code: 403
# Failed to get video ID for title: Monsters University at index 649 with status code: 403
# Failed to get video ID for title: Despicable Me 2 at index 655 with status code: 403
# Failed to get video ID for title: The Smurfs 2 at index 671 with status code: 403
# Failed to get video ID for title: Planes at index 679 with status code: 403
# Failed to get video ID for title: Frozen at index 729 with status code: 403
# Failed to get video ID for title: Walking with Dinosaurs at index 740 with status code: 403
# Failed to get video ID for title: The Nut Job at index 751 with status code: 403
# Failed to get video ID for title: The Lego Movie at index 756 with status code: 403
# Failed to get video ID for title: Mr. Peabody & Sherman at index 770 with status code: 403
# Failed to get video ID for title: Muppets Most Wanted at index 778 with status code: 403
# Failed to get video ID for title: Rio 2 at index 785 with status code: 403
# Failed to get video ID for title: Million Dollar Arm at index 796 with status code: 403
# Failed to get video ID for title: Maleficent at index 799 with status code: 403
# Failed to get video ID for title: How to Train Your Dragon 2 at index 805 with status code: 403
# Failed to get video ID for title: Planes: Fire & Rescue at index 821 with status code: 403
# Failed to get video ID for title: Teenage Mutant Ninja Turtles at index 835 with status code: 403
# Failed to get video ID for title: Dolphin Tale 2 at index 847 with status code: 403
# Failed to get video ID for title: The Boxtrolls at index 855 with status code: 403
# Failed to get video ID for title: Alexander and the Terrible, Horrible, No Good, Very Bad Day at index 862 with status code: 403
# Failed to get video ID for title: The Book of Life at index 867 with status code: 403
# Failed to get video ID for title: Dear White People at index 869 with status code: 403
# Failed to get video ID for title: Big Hero 6 at index 876 with status code: 403
# Failed to get video ID for title: Penguins of Madagascar at index 885 with status code: 403
# Failed to get video ID for title: Into the Woods at index 897 with status code: 403
# Failed to get video ID for title: Black or White at index 910 with status code: 403
# Failed to get video ID for title: The SpongeBob Movie: Sponge Out of Water at index 916 with status code: 403
# Failed to get video ID for title: McFarland, USA at index 924 with status code: 403
# Failed to get video ID for title: Cinderella at index 931 with status code: 403
# Failed to get video ID for title: Home at index 941 with status code: 403
# Failed to get video ID for title: Tomorrowland at index 964 with status code: 403
# Failed to get video ID for title: Minions at index 974 with status code: 403
# Failed to get video ID for title: Hotel Transylvania 2 at index 1007 with status code: 403
# Failed to get video ID for title: Jem and the Holograms at index 1026 with status code: 403
# Failed to get video ID for title: The Peanuts Movie at index 1035 with status code: 403
# Failed to get video ID for title: The Good Dinosaur at index 1045 with status code: 403
# Failed to get video ID for title: Alvin and the Chipmunks: The Road Chip at index 1050 with status code: 403
# Failed to get video ID for title: Norm of the North at index 1063 with status code: 403
# Failed to get video ID for title: Kung Fu Panda 3 at index 1067 with status code: 403
# Failed to get video ID for title: Zootopia at index 1082 with status code: 403
# Failed to get video ID for title: The Jungle Book at index 1106 with status code: 403
# Failed to get video ID for title: Ratchet & Clank at index 1115 with status code: 403
# Failed to get video ID for title: The Angry Birds Movie at index 1119 with status code: 403
# Failed to get video ID for title: Alice Through the Looking Glass at index 1123 with status code: 403
# Failed to get video ID for title: Teenage Mutant Ninja Turtles: Out of the Shadows at index 1124 with status code: 403
# Failed to get video ID for title: Finding Dory at index 1130 with status code: 403
# Failed to get video ID for title: The BFG at index 1138 with status code: 403
# Failed to get video ID for title: The Secret Life of Pets at index 1140 with status code: 403
# Failed to get video ID for title: Kubo and the Two Strings at index 1158 with status code: 403
# Failed to get video ID for title: Storks at index 1173 with status code: 403
# Failed to get video ID for title: Masterminds at index 1177 with status code: 403
# Failed to get video ID for title: Max Steel at index 1183 with status code: 403
# Failed to get video ID for title: Trolls at index 1192 with status code: 403
# Failed to get video ID for title: Loving at index 1194 with status code: 403
# Failed to get video ID for title: Moana at index 1200 with status code: 403
# Failed to get video ID for title: Sing at index 1212 with status code: 403
# Failed to get video ID for title: A Dog's Purpose at index 1227 with status code: 403
# Failed to get video ID for title: Growing Up Smith at index 1232 with status code: 403
# Failed to get video ID for title: The Lego Batman Movie at index 1233 with status code: 403
# Failed to get video ID for title: Rock Dog at index 1241 with status code: 403
# Failed to get video ID for title: Beauty and the Beast at index 1248 with status code: 403
# Failed to get video ID for title: The Boss Baby at index 1255 with status code: 403
# Failed to get video ID for title: Smurfs: The Lost Village at index 1258 with status code: 403
# Failed to get video ID for title: The Promise at index 1268 with status code: 403
# Failed to get video ID for title: Diary of a Wimpy Kid: The Long Haul at index 1279 with status code: 403
# Failed to get video ID for title: Captain Underpants: The First Epic Movie at index 1284 with status code: 403
# Failed to get video ID for title: Cars 3 at index 1288 with status code: 403
# Failed to get video ID for title: Despicable Me 3 at index 1299 with status code: 403
# Failed to get video ID for title: Kidnap at index 1314 with status code: 403
# Failed to get video ID for title: The Lego Ninjago Movie at index 1331 with status code: 403
# Failed to get video ID for title: My Little Pony: The Movie at index 1340 with status code: 403
# Failed to get video ID for title: Coco at index 1368 with status code: 403
# Failed to get video ID for title: Call Me by Your Name at index 1369 with status code: 403
# Failed to get video ID for title: Ferdinand at index 1376 with status code: 403
# Failed to get video ID for title: The Greatest Showman at index 1379 with status code: 403
# Failed to get video ID for title: Incredibles 2 at index 1451 with status code: 403
# Failed to get video ID for title: Hotel Transylvania 3: Summer Vacation at index 1462 with status code: 403
# Failed to get video ID for title: Teen Titans Go! To the Movies at index 1471 with status code: 403
# Failed to get video ID for title: Christopher Robin at index 1472 with status code: 403
# Failed to get video ID for title: The Grinch at index 1529 with status code: 403
# Failed to get video ID for title: Spider-Man: Into the Spider-Verse at index 1544 with status code: 403
# Failed to get video ID for title: The Kid Who Would Be King at index 1562 with status code: 403
# Failed to get video ID for title: The Lego Movie 2: The Second Part at index 1565 with status code: 403
# Failed to get video ID for title: How to Train Your Dragon: The Hidden World at index 1572 with status code: 403
# Failed to get video ID for title: Nancy Drew and the Hidden Staircase at index 1578 with status code: 403
# Failed to get video ID for title: Missing Link at index 1593 with status code: 403
# Failed to get video ID for title: UglyDolls at index 1602 with status code: 403
# Failed to get video ID for title: Pokémon Detective Pikachu at index 1603 with status code: 403
# Failed to get video ID for title: The Secret Life of Pets 2 at index 1616 with status code: 403
# Failed to get video ID for title: Toy Story 4 at index 1621 with status code: 403
# Failed to get video ID for title: The Lion King at index 1631 with status code: 403
# Failed to get video ID for title: The Angry Birds Movie 2 at index 1639 with status code: 403
# Failed to get video ID for title: Abominable at index 1655 with status code: 403
# Failed to get video ID for title: Frozen 2 at index 1687 with status code: 403
# Failed to get video ID for title: Spies in Disguise at index 1703 with status code: 403
# Failed to get video ID for title: Onward at index 1727 with status code: 403
# Failed to get video ID for title: Trolls World Tour at index 1734 with status code: 403
# Failed to get video ID for title: Scoob! at index 1737 with status code: 403
# Failed to get video ID for title: The SpongeBob Movie: Sponge on the Run at index 1748 with status code: 403
# Failed to get video ID for title: A Rainy Day in New York at index 1763 with status code: 403
# Failed to get video ID for title: Fatman at index 1776 with status code: 403
# Failed to get video ID for title: The Croods: A New Age at index 1780 with status code: 403
# Failed to get video ID for title: Tom & Jerry at index 1803 with status code: 403
# Failed to get video ID for title: Spirit Untamed at index 1821 with status code: 403
# Failed to get video ID for title: Wish Dragon at index 1825 with status code: 403
# Failed to get video ID for title: The Boss Baby: Family Business at index 1834 with status code: 403
# Failed to get video ID for title: Sing 2 at index 1892 with status code: 403
# Failed to get video ID for title: Hotel Transylvania: Transformania at index 1900 with status code: 403
# Failed to get video ID for title: Sonic the Hedgehog 2 at index 1922 with status code: 403
# Failed to get video ID for title: The Bad Guys at index 1927 with status code: 403
# Failed to get video ID for title: Chip 'n Dale: Rescue Rangers at index 1934 with status code: 403
# Failed to get video ID for title: Lightyear at index 1939 with status code: 403
# Failed to get video ID for title: Minions: The Rise of Gru at index 1942 with status code: 403
# Failed to get video ID for title: Puss in Boots: The Last Wish at index 1991 with status code: 403

# %%
df = pd.DataFrame(movieCommentsList)
df_Failures = pd.DataFrame(movieFailuresList)

# %%
df.to_csv('MovieComments.csv', index=False)
df_Failures.to_csv('MovieFailures.csv', index=False)
