# %% [markdown]
# The neccessary code is already provided.
# Just run the code.
#
# 4 things need to be altered after each iteration:
# 1. The read_csv file name
# 2. The startindex
# 3. The apiKey
# 4. The output file name
#
# Output file number and apiKey number will be the same.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('WikipediaMovieDatasetWithTrailerIDs.csv')

df.head()
# Out:
#              Title           Directed by  \
# 0      Daybreakers  The Spierig Brothers
# 1        Leap Year          Anand Tucker
# 2  Youth in Revolt         Miguel Arteta
# 3  Wonderful World         Joshua Goldin
# 4  The Book of Eli   The Hughes Brothers
#
#                                          Produced by       Cinematography  \
# 0       ['Chris Brown', 'Sean Furst', 'Bryan Furst']             Ben Nott
# 1  ['Gary Barber', 'Chris Bender', 'Roger Birnbau...  Newton Thomas Sigel
# 2                                       David Permut          Chuy Chávez
# 3  ['Miranda Bailey', 'Matthew Leutwyler', 'Glenn...       Daniel Shulman
# 4  ['Joel Silver', 'Denzel Washington', 'Broderic...          Don Burgess
#
#          Country  Running Time (int) Release Date (datetime)  \
# 0            NaN                98.0              2009-09-11
# 1            NaN               100.0              2010-01-06
# 2  United States                89.0              2009-10-19
# ...

# %%
movieInfo = df.iloc[1292]
print(movieInfo)
# Out:
# Title                                                      The Book of Henry
# Directed by                                                  Colin Trevorrow
# Produced by                ['Sidney Kimmel', 'Carla Hacken', 'Jenette Kah...
# Cinematography                                              John Schwartzman
# Country                                                        United States
# Running Time (int)                                                     105.0
# Release Date (datetime)                                           2017-06-14
# Distributed by                                                Focus Features
# Language                                                             English
# Written by                                                     Gregg Hurwitz
# Starring                   ['Naomi Watts', 'Jaeden Lieberher', 'Jacob Tre...
# Edited by                                                        Kevin Stitt
# ...

# %%
import requests
import json
from urllib.parse import quote

def formatQuery(query):
    return quote(query, safe='')

apiKey = 'AIzaSyB-D3yV9I4Sbi0E2Zi19h6FoPOaLUveIxE'
apiKey10 = 'AIzaSyAKCEF55rQUIZj5bma5gf7aSZDTu8WFiF0'
apiKey11 = 'AIzaSyC8VjUjr_22_ZGKrutUOiUITmn7vsMQeOs'
apiKey12 = 'AIzaSyAHyJNk4Y9n05C9WKLS1P2BYHUAL6rFfyw'

maxResults = '1'
startingIndex = 0

# Iterate over each row in the DataFrame
for index, row in df.iloc[startingIndex:1698].iterrows():
    title = row['Title']
    year = str(row['Release Year'])
    suffix = 'Official Movie Trailer'
    query = f'{title} {year} {suffix}'
    formattedQuery = formatQuery(query)

    request = f'https://youtube.googleapis.com/youtube/v3/search?part=snippet&maxResults={maxResults}&q={formattedQuery}&type=video&key={apiKey}'

    response = requests.get(request)

    # If the request was successful, the status code will be 200
    if response.status_code == 200:
        # Extract the video ID from the response
        videoID = response.json()['items'][0]['id']['videoId']
        videoTitle = response.json()['items'][0]['snippet']['title'] 
        # Store the video ID in the corresponding row of the DataFrame
        df.at[index, 'Trailer ID'] = videoID
        df.at[index, 'Trailer Title'] = videoTitle
    else:
        df.at[index, 'Trailer ID'] = np.nan
        df.at[index, 'Trailer Title'] = np.nan
        print(f'Failed to get video ID for title: {title} at index {index}')

df.head()
# Out:
# Failed to get video ID for title: Bombshell at index 1697
#              Title           Directed by  \
# 0      Daybreakers  The Spierig Brothers
# 1        Leap Year          Anand Tucker
# 2  Youth in Revolt         Miguel Arteta
# 3  Wonderful World         Joshua Goldin
# 4  The Book of Eli   The Hughes Brothers
#
#                                          Produced by       Cinematography  \
# 0       ['Chris Brown', 'Sean Furst', 'Bryan Furst']             Ben Nott
# 1  ['Gary Barber', 'Chris Bender', 'Roger Birnbau...  Newton Thomas Sigel
# 2                                       David Permut          Chuy Chávez
# 3  ['Miranda Bailey', 'Matthew Leutwyler', 'Glenn...       Daniel Shulman
# 4  ['Joel Silver', 'Denzel Washington', 'Broderic...          Don Burgess
#
#          Country  Running Time (int) Release Date (datetime)  \
# 0            NaN                98.0              2009-09-11
# 1            NaN               100.0              2010-01-06
# ...

# %%
df.to_csv('WikipediaMovieDatasetWithTrailerIDs.csv', index=False)
